# %%
using BayesNets
using DataFrames
using Discretizers
using LightGraphs
include("k2Algorithm.jl")
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /Users/mwb/.julia/v0.5/StatsBase/src/scalarstats.jl:560 overwritten in module DataFrames at /Users/mwb/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# main (generic function with 3 methods)

# %%
# initialize our type object
# similar to a class object in python except we can not add more attributes to it
type DataObj_type
        VarNumber
        CaseLength
        VarSample
        VarRange
        VarRangeLength
end

# %%
main("titanic.csv",1000000)
main("whitewine.csv",50000)
main("schoolgrades.csv",4000)

# %% [markdown]
# Not included here, but if you would like to generate the plots that were featured in the document, comment out the above cell and uncomment the code below. Below is for demonstration purposes and reflects only a few K2 iterations.

# %%
using TikzGraphs

titanicDAG, titanicGraph, titanicNames, titanicBS = main("../titanic.csv",100,true)
titanicPlotNames = convertNames2string(titanicNames)
TikzGraphs.plot(titanicGraph,titanicPlotNames)

# follow the same procedure for "Whitewine" and "Schoolgrades"
# Out:
# elapsed time: 10.00993585 seconds
# TikzPictures.TikzPicture("\\graph [layered layout, ] {\n1/\"age\" [],\n2/\"portembarked\" [],\n3/\"fare\" [],\n4/\"numparentschildren\" [],\n5/\"passengerclass\" [],\n6/\"sex\" [],\n7/\"numsiblings\" [],\n8/\"survived\" [],\n;\n2 -> [,] 8;\n3 -> [,] 5;\n3 -> [,] 7;\n4 -> [,] 1;\n4 -> [,] 6;\n4 -> [,] 8;\n5 -> [,] 1;\n5 -> [,] 2;\n5 -> [,] 6;\n5 -> [,] 8;\n7 -> [,] 1;\n7 -> [,] 4;\n7 -> [,] 5;\n8 -> [,] 6;\n};\n","","\\usepackage{fontspec}\n\\setmainfont{Latin Modern Math}\n\\usetikzlibrary{graphs}\n\\usetikzlibrary{graphdrawing}\n\n\\usegdlibrary{layered}",true,true)
